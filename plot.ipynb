# %%
import json
import os
from collections import defaultdict

# %%
json_file = "all_20_0_20250321162423_rl/2048_steps_pool.json" 

with open(json_file, "r", encoding="utf-8") as f:
    data = json.load(f)

print(json.dumps(data, indent=4, ensure_ascii=False))
# Out:
# {
#     "exprs": [
#         "Div(Sub(30.0,$vwap),30.0)",
#         "Log(Add(30.0,$high))",
#         "$volume",
#         "Less(Mul(Div(Cov(Less($high,5.0),Greater($close,-10.0),1d),$close),$high),0.01)",
#         "Abs(Div(Less(Greater(Greater(Add(Add($close,-0.5),$low),-2.0),$low),5.0),-1.0))",
#         "EMA(Abs($low),10d)"
#     ],
#     "weights": [
#         -0.010202650484130228,
#         -0.04886982710319347,
#         -3.100981717286955e-05,
#         9.825943131966126e-05,
#         -0.013026718211689083,
#         0.021125796019654575
#     ]
# }

# %%
import matplotlib.pyplot as plt

top_factors = sorted(factor_counts.items(), key=lambda x: x[1], reverse=True)[:10]
factors, counts = zip(*top_factors)

plt.figure(figsize=(12, 6))
plt.barh(factors, counts, color='royalblue')
plt.xlabel("Frequency")
plt.ylabel("Factors")
plt.title("Top 10 Most Frequent Factors")
plt.gca().invert_yaxis()

plt.show()

# %%
json_dir = "all_20_0_20250321162423_rl/"


factor_counts = defaultdict(int)


for filename in os.listdir(json_dir):
    if filename.endswith(".json"):
        file_path = os.path.join(json_dir, filename)
        
        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)

        if "exprs" in data:
            for expr in data["exprs"]:
                factor_counts[expr] += 1 

print(dict(factor_counts))
